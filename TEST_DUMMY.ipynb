# %% [markdown]
# # MAIN LIBRARIES

# %%
# %run "./UnmovedFlow.ipynb"

# %%
# Make Sample Data
X_train, X_test, y_train, y_test = make_sample_data(task='classification')

# Show the first five rows of the dataset
pd.DataFrame(X_train).head()

# Instantiate and fit a basic Logistic Regression model
lr = LogisticRegression()
lr.fit(X_train, y_train)

evaluate_binary_model(lr, 'LOGISTIC CLASSIFIER', X_train, X_test, y_train, y_test)
# Out:
# [LOGISTIC CLASSIFIER] Training Mean 5-Fold CV Score: 79.25%
# [LOGISTIC CLASSIFIER] Test Set Accuracy Score: 76.50%
# [LOGISTIC CLASSIFIER] Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77       100
#            1       0.77      0.76      0.76       100
#
#     accuracy                           0.77       200
#    macro avg       0.77      0.77      0.76       200
# weighted avg       0.77      0.77      0.76       200

# %%
# Preview PCA
pca_preview(X_train, X_test)
# Out:
# Train Data:
# [OPTIMAL PCA COMPONENTS BY KAISER CRITERION (Train Data)]:
#  0
# According to Kaiser criterion, PCA might not be necessary.
#
# [EXPLAINED VARIANCE PER COMPONENT (Train Data)]:
# Component 1: 0.3746
# Component 2: 0.1957
# Component 3: 0.1568
# Component 4: 0.1193
# Component 5: 0.0640
# Component 6: 0.0519
# Component 7: 0.0376
# Component 8: 0.0000
# Component 9: 0.0000
# Component 10: 0.0000
#
# [CUMULATIVE VARIANCE PER COMPONENT (Train Data)]:
# Components 1: 0.3746
# Components 2: 0.5704
# Components 3: 0.7272
# Components 4: 0.8464
# Components 5: 0.9104
# Components 6: 0.9624
# Components 7: 1.0000
# Components 8: 1.0000
# Components 9: 1.0000
# Components 10: 1.0000
#
# Test Data:
# [OPTIMAL PCA COMPONENTS BY KAISER CRITERION (Test Data)]:
#  0
# According to Kaiser criterion, PCA might not be necessary.
#
# [EXPLAINED VARIANCE PER COMPONENT (Test Data)]:
# Component 1: 0.3549
# Component 2: 0.2217
# Component 3: 0.1583
# Component 4: 0.1230
# Component 5: 0.0697
# Component 6: 0.0415
# Component 7: 0.0311
# Component 8: 0.0000
# Component 9: 0.0000
# Component 10: 0.0000
#
# [CUMULATIVE VARIANCE PER COMPONENT (Test Data)]:
# Components 1: 0.3549
# Components 2: 0.5765
# Components 3: 0.7349
# Components 4: 0.8578
# Components 5: 0.9275
# Components 6: 0.9689
# Components 7: 1.0000
# Components 8: 1.0000
# Components 9: 1.0000
# Components 10: 1.0000
