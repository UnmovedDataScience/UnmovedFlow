# %% [markdown]
# # MAIN LIBRARIES

# %%
# %run "./UnmovedFlow.ipynb"

# %%
# Make a 10 feature dataset with 1000 samples and split it
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Show the first five rows of the dataset
pd.DataFrame(X_train).head()

# Instantiate and fit a basic Logistic Regression model
lr = LogisticRegression()
lr.fit(X_train, y_train)

evaluate_binary_model(lr, 'LOGISTIC CLASSIFIER', X_train, X_test, y_train, y_test)
# Out:
# [LOGISTIC CLASSIFIER] Training Mean 5-Fold CV Score: 82.00%
# [LOGISTIC CLASSIFIER] Test Set Accuracy Score: 79.20%
# [LOGISTIC CLASSIFIER] Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80       121
#            1       0.83      0.74      0.79       129
#
#     accuracy                           0.79       250
#    macro avg       0.80      0.79      0.79       250
# weighted avg       0.80      0.79      0.79       250
