# %% [markdown]
# # MAIN LIBRARIES

# %%
# %run "./UnmovedFlow.ipynb"

# %%
# Make Sample Data
X_train, X_test, y_train, y_test = make_sample_data(task='classification')

# Show the first five rows of the dataset
pd.DataFrame(X_train).head()

BinaryFlow(X_train, X_test, y_train, y_test)
# Out:
# [LOGISTIC REGRESSION CLASSIFIER] Training Mean 5-Fold CV Score: 79.25%
# [LOGISTIC REGRESSION CLASSIFIER] Test Set Accuracy Score: 76.50%
# [LOGISTIC REGRESSION CLASSIFIER] Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77       100
#            1       0.77      0.76      0.76       100
#
#     accuracy                           0.77       200
#    macro avg       0.77      0.77      0.76       200
# weighted avg       0.77      0.77      0.76       200
# [NAIVE BAYES CLASSIFIER] Training Mean 5-Fold CV Score: 80.75%
# [NAIVE BAYES CLASSIFIER] Test Set Accuracy Score: 80.50%
# [NAIVE BAYES CLASSIFIER] Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80       100
#            1       0.80      0.81      0.81       100
#
#     accuracy                           0.81       200
#    macro avg       0.81      0.81      0.80       200
# ...
